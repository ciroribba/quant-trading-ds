# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.7.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.16.3-cp310-abi3-macosx_11_0_arm64.whl.metadata (17 kB)
# Requirement already satisfied: lxml>=4.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (5.2.1)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.3.3)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.5.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Collecting cffi>=2.0.0 (from curl_cffi>=0.15->yfinance)
#   Downloading cffi-2.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from curl_cffi>=0.15->yfinance) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Downloading yfinance-1.7.0-py3-none-any.whl (149 kB)
# Downloading curl_cffi-0.16.3-cp310-abi3-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 14.7 MB/s eta 0:00:00
# Downloading multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading peewee-4.5.1-py3-none-any.whl (193 kB)
# Downloading websockets-17.1-cp312-cp312-macosx_11_0_arm64.whl (214 kB)
# Downloading cffi-2.1.1-cp312-cp312-macosx_11_0_arm64.whl (184 kB)
# Installing collected packages: multitasking, websockets, peewee, cffi, curl_cffi, yfinance
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
# Successfully installed cffi-2.1.1 curl_cffi-0.16.3 multitasking-0.0.13 peewee-4.5.1 websockets-17.1 yfinance-1.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

print(yf.__version__)
# Out:
# 1.7.0

# %%
btc = yf.download(
    "BTC-USD",
    start="2018-01-01",
    auto_adjust=False
)

btc.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Adj Close         Close          High           Low  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2018-01-01  13657.200195  13657.200195  14112.200195  13154.700195
# 2018-01-02  14982.099609  14982.099609  15444.599609  13163.599609
# 2018-01-03  15201.000000  15201.000000  15572.799805  14844.500000
# 2018-01-04  15599.200195  15599.200195  15739.700195  14522.200195
# 2018-01-05  17429.500000  17429.500000  17705.199219  15202.799805
#
# Price               Open       Volume
# Ticker           BTC-USD      BTC-USD
# Date
# 2018-01-01  14112.200195  10291200000
# 2018-01-02  13625.000000  16846600192
# 2018-01-03  14978.200195  16871900160
# 2018-01-04  15270.700195  21783199744
# 2018-01-05  15477.200195  23840899072

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3179 entries, 2018-01-01 to 2026-09-14
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, BTC-USD)  3179 non-null   float64
#  1   (Close, BTC-USD)      3179 non-null   float64
#  2   (High, BTC-USD)       3179 non-null   float64
#  3   (Low, BTC-USD)        3179 non-null   float64
#  4   (Open, BTC-USD)       3179 non-null   float64
#  5   (Volume, BTC-USD)     3179 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 173.9 KB

# %%
btc.describe()
# Out:
# Price       Adj Close          Close           High            Low  \
# Ticker        BTC-USD        BTC-USD        BTC-USD        BTC-USD
# count     3179.000000    3179.000000    3179.000000    3179.000000
# mean     40123.108212   40123.108212   40876.392790   39282.871677
# std      32445.207200   32445.207200   32954.892338   31892.722040
# min       3236.761719    3236.761719    3275.377930    3191.303467
# 25%       9879.864258    9879.864258   10150.827148    9663.968262
# 50%      30145.888672   30145.888672   30601.740234   29570.302734
# 75%      63542.017578   63542.017578   64488.035156   62398.693359
# max     124752.531250  124752.531250  126198.070312  123196.046875
#
# Price            Open        Volume
# Ticker        BTC-USD       BTC-USD
# count     3179.000000  3.179000e+03
# mean     40103.966387  3.060624e+10
# std      32441.634526  2.160102e+10
# min       3236.274658  2.923670e+09
# 25%       9879.447754  1.588282e+10
# 50%      30140.685547  2.669970e+10
# 75%      63529.781250  4.017926e+10
# max     124752.140625  3.509679e+11

# %%
btc.isna().sum()
# Out:
# Price      Ticker
# Adj Close  BTC-USD    0
# Close      BTC-USD    0
# High       BTC-USD    0
# Low        BTC-USD    0
# Open       BTC-USD    0
# Volume     BTC-USD    0
# dtype: int64

# %%
btc["Close"].plot(
    figsize=(14, 6),
    title="Bitcoin - Precio de cierre"
)

plt.xlabel("Fecha")
plt.ylabel("Precio USD")
plt.show()

# %%
btc.to_csv("../data/raw/btc_usd.csv")
